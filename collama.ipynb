# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulRahmanS2022/Deploy-python-/blob/main/collama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,506 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,454 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏ 1.2 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   1% ▕▏  19 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   2% ▕▏  44 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   3% ▕▏  61 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   5% ▕▏  97 MB/2.0 GB                  pulling manifest
# ...

# %%
# !pip install langchain-ollama

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM
from IPython.display import Markdown

template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="llama3.2")

chain = prompt | model

display(Markdown(chain.invoke({"question": "What is the easiest way to learn about hugging face"})))
# Out:
# Here are some steps to help you get started with Hugging Face:
#
# 1. **Understand what Hugging Face is**: Hugging Face is a popular open-source platform for natural language processing (NLP) and computer vision tasks. It provides a wide range of pre-trained models, libraries, and tools for NLP and CV tasks.
#
# 2. **Familiarize yourself with the Hugging Face ecosystem**: Hugging Face has many products and services, including Transformers, AutoModelForSequenceClassification, and more. Start by exploring these products to see which one aligns best with your goals.
#
# 3. **Start with some tutorials or guides**: Hugging Face provides an extensive tutorial on their website, covering the basics of how to use their platform. You can also check out online courses, blogs, and forums for additional learning resources.
#
# ...
